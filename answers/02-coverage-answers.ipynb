# %%
import pandas
import pulp
import geopandas # standard library for geographical data in Python
import numpy # standard library for numerical and array-based computing
import spopt # library for spatial optimisation

# %%
postcodes = pandas.read_csv("../uk_postcodes.csv")

# spatialize the data
postcodes = geopandas.GeoDataFrame(
    postcodes, 
    geometry=geopandas.points_from_xy(postcodes.lon, postcodes.lat, crs="epsg:4326")
)

bristol_postcodes = postcodes[postcodes.outward.str.startswith("BS")].copy()

# is the postcode in the center of the city? 
is_inner_city = bristol_postcodes.outward.str.lstrip("BS").astype(int) < 10

# if so, keep it around
bristol_innercity = bristol_postcodes[is_inner_city].copy()

# convert the data to utm for distance calculations: 
bristol_innercity_utm = bristol_innercity.to_crs(
    bristol_innercity.estimate_utm_crs()
)
bristol_postcodes = bristol_postcodes.to_crs(
    bristol_postcodes.estimate_utm_crs()
)

# %% [markdown]
# # Do: fit your own coverage problems!
#
# Now it is time for you to try your hand at solving coverage problems.
#
# ## One again, with feeling
#
# <div class="alert alert-warning">
#
# Using the methods we discussed above, can you create a new LSCP problem object to cover all Bristol post codes using a 5000 meter service radius? How many facilities are needed, and in which postcode are they located?
#
# </div>

# %%
lscp1 = spopt.locate.LSCP.from_geodataframe(
    gdf_demand=bristol_postcodes,
    gdf_fac=bristol_postcodes,
    service_radius = 5000,
    demand_col="geometry", 
    facility_col="geometry",
).solve(pulp.COIN_CMD(msg=False))

# %%
lscp1

# %%
lscp1.problem
# Out:
# lscp:
# MINIMIZE
# 1*y_0_ + 1*y_10_ + 1*y_11_ + 1*y_12_ + 1*y_13_ + 1*y_14_ + 1*y_15_ + 1*y_16_ + 1*y_17_ + 1*y_18_ + 1*y_19_ + 1*y_1_ + 1*y_20_ + 1*y_21_ + 1*y_22_ + 1*y_23_ + 1*y_24_ + 1*y_25_ + 1*y_26_ + 1*y_27_ + 1*y_28_ + 1*y_29_ + 1*y_2_ + 1*y_30_ + 1*y_31_ + 1*y_32_ + 1*y_33_ + 1*y_34_ + 1*y_35_ + 1*y_36_ + 1*y_37_ + 1*y_38_ + 1*y_39_ + 1*y_3_ + 1*y_40_ + 1*y_41_ + 1*y_42_ + 1*y_4_ + 1*y_5_ + 1*y_6_ + 1*y_7_ + 1*y_8_ + 1*y_9_ + 0
# SUBJECT TO
# _C1: y_0_ + y_11_ + y_22_ + y_31_ + y_34_ + y_37_ + y_38_ + y_39_ + y_3_
#  + y_41_ + y_42_ + y_4_ + y_8_ >= 1
#
# _C2: y_1_ + y_26_ >= 1
#
# _C3: y_2_ + y_42_ >= 1
#
# _C4: y_0_ + y_38_ + y_39_ + y_3_ + y_42_ + y_8_ >= 1
#
# _C5: y_0_ + y_11_ + y_22_ + y_31_ + y_34_ + y_37_ + y_38_ + y_41_ + y_42_
#  + y_4_ + y_8_ >= 1
#
# _C6: y_24_ + y_30_ + y_31_ + y_5_ + y_9_ >= 1
#
# _C7: y_23_ + y_28_ + y_6_ + y_7_ >= 1
#
# _C8: y_23_ + y_28_ + y_38_ + y_39_ + y_6_ + y_7_ + y_8_ >= 1
#
# _C9: y_0_ + y_11_ + y_31_ + y_37_ + y_38_ + y_39_ + y_3_ + y_4_ + y_7_ + y_8_
#  >= 1
#
# _C10: y_30_ + y_5_ + y_9_ >= 1
#
# _C11: y_10_ >= 1
#
# _C12: y_0_ + y_11_ + y_22_ + y_31_ + y_34_ + y_37_ + y_38_ + y_41_ + y_42_
#  + y_4_ + y_8_ >= 1
#
# _C13: y_12_ >= 1
#
# _C14: y_13_ >= 1
#
# _C15: y_14_ + y_17_ + y_21_ + y_36_ >= 1
#
# _C16: y_15_ >= 1
#
# _C17: y_16_ + y_21_ >= 1
#
# _C18: y_14_ + y_17_ + y_18_ + y_21_ >= 1
#
# _C19: y_17_ + y_18_ >= 1
#
# _C20: y_19_ + y_32_ >= 1
#
# _C21: y_20_ >= 1
#
# _C22: y_14_ + y_16_ + y_17_ + y_21_ >= 1
#
# _C23: y_0_ + y_11_ + y_22_ + y_31_ + y_33_ + y_34_ + y_41_ + y_4_ >= 1
#
# _C24: y_23_ + y_28_ + y_6_ + y_7_ >= 1
#
# _C25: y_24_ + y_30_ + y_31_ + y_5_ >= 1
#
# _C26: y_25_ + y_27_ >= 1
#
# _C27: y_1_ + y_26_ + y_28_ >= 1
#
# _C28: y_25_ + y_27_ >= 1
#
# _C29: y_23_ + y_26_ + y_28_ + y_6_ + y_7_ >= 1
#
# _C30: y_29_ + y_40_ >= 1
#
# _C31: y_24_ + y_30_ + y_5_ + y_9_ >= 1
#
# _C32: y_0_ + y_11_ + y_22_ + y_24_ + y_31_ + y_34_ + y_37_ + y_38_ + y_41_
#  + y_4_ + y_5_ + y_8_ >= 1
#
# _C33: y_19_ + y_32_ >= 1
#
# _C34: y_22_ + y_33_ + y_34_ + y_41_ >= 1
#
# _C35: y_0_ + y_11_ + y_22_ + y_31_ + y_33_ + y_34_ + y_37_ + y_38_ + y_41_
#  + y_4_ >= 1
#
# _C36: y_35_ >= 1
#
# _C37: y_14_ + y_36_ >= 1
#
# _C38: y_0_ + y_11_ + y_31_ + y_34_ + y_37_ + y_38_ + y_39_ + y_41_ + y_4_
#  + y_8_ >= 1
#
# _C39: y_0_ + y_11_ + y_31_ + y_34_ + y_37_ + y_38_ + y_39_ + y_3_ + y_4_
#  + y_7_ + y_8_ >= 1
#
# _C40: y_0_ + y_37_ + y_38_ + y_39_ + y_3_ + y_7_ + y_8_ >= 1
#
# _C41: y_29_ + y_40_ >= 1
#
# _C42: y_0_ + y_11_ + y_22_ + y_31_ + y_33_ + y_34_ + y_37_ + y_41_ + y_42_
#  + y_4_ >= 1
#
# _C43: y_0_ + y_11_ + y_2_ + y_3_ + y_41_ + y_42_ + y_4_ >= 1
#
# VARIABLES
# 0 <= y_0_ <= 1 Integer
# 0 <= y_10_ <= 1 Integer
# 0 <= y_11_ <= 1 Integer
# 0 <= y_12_ <= 1 Integer
# 0 <= y_13_ <= 1 Integer
# 0 <= y_14_ <= 1 Integer
# 0 <= y_15_ <= 1 Integer
# 0 <= y_16_ <= 1 Integer
# 0 <= y_17_ <= 1 Integer
# 0 <= y_18_ <= 1 Integer
# 0 <= y_19_ <= 1 Integer
# 0 <= y_1_ <= 1 Integer
# 0 <= y_20_ <= 1 Integer
# 0 <= y_21_ <= 1 Integer
# 0 <= y_22_ <= 1 Integer
# 0 <= y_23_ <= 1 Integer
# 0 <= y_24_ <= 1 Integer
# 0 <= y_25_ <= 1 Integer
# 0 <= y_26_ <= 1 Integer
# 0 <= y_27_ <= 1 Integer
# 0 <= y_28_ <= 1 Integer
# 0 <= y_29_ <= 1 Integer
# 0 <= y_2_ <= 1 Integer
# 0 <= y_30_ <= 1 Integer
# 0 <= y_31_ <= 1 Integer
# 0 <= y_32_ <= 1 Integer
# 0 <= y_33_ <= 1 Integer
# 0 <= y_34_ <= 1 Integer
# 0 <= y_35_ <= 1 Integer
# 0 <= y_36_ <= 1 Integer
# 0 <= y_37_ <= 1 Integer
# 0 <= y_38_ <= 1 Integer
# 0 <= y_39_ <= 1 Integer
# 0 <= y_3_ <= 1 Integer
# 0 <= y_40_ <= 1 Integer
# 0 <= y_41_ <= 1 Integer
# 0 <= y_42_ <= 1 Integer
# 0 <= y_4_ <= 1 Integer
# 0 <= y_5_ <= 1 Integer
# 0 <= y_6_ <= 1 Integer
# 0 <= y_7_ <= 1 Integer
# 0 <= y_8_ <= 1 Integer
# 0 <= y_9_ <= 1 Integer

# %%
bristol_postcodes.assign(
    allocation = [str(assignment) for assignment in lscp1.cli2fac]
).explore('allocation',
         marker_kwds=dict(radius=10),
          cmap='Dark2'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95a97cef1def66b5d32fa988789a6758 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend allocation&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;allocation&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[10]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[12]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[13]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[15]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[16]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[18]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[19]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[1]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[20]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[25]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[29]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[30]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[35]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[36]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[41, 42]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[41]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[42]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[7]&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95a97cef1def66b5d32fa988789a6758&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95a97cef1def66b5d32fa988789a6758 = L.map(
#                 &quot;map_95a97cef1def66b5d32fa988789a6758&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_95a97cef1def66b5d32fa988789a6758);
#
#
#
#
#
#             var tile_layer_408c3451c030801f31023befe8962e41 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blan

# %%
chosen = [len(clients) > 0 for clients in lscp1.fac2cli]

# %%
sum(chosen)
# Out:
# 17

# %%
bristol_postcodes.assign(
    chosen=chosen
).explore('chosen',
        marker_kwds=dict(radius=10),
          cmap='Dark2'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a24363540e09f99c249e16921e4dd6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend chosen&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;chosen&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;False&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;True&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a24363540e09f99c249e16921e4dd6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a24363540e09f99c249e16921e4dd6e = L.map(
#                 &quot;map_0a24363540e09f99c249e16921e4dd6e&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0a24363540e09f99c249e16921e4dd6e);
#
#
#
#
#
#             var tile_layer_3514e55ca6f5e7c10cd4db3e5348e18c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a24363540e09f99c249e16921e4dd6e);
#
#
#             map_0a24363540e09f99c249e16921e4dd6e.fitBounds(
#                 [[51.223946999999995, -2.991015], [51.646466999999994, -2.194994]],
#                 {}
#             );
#
#
#         function geo_json_17aa4f2258207f88e2b8cc7f36eea7df_styler(feature) {
#             switch(feature.id) {
#                 case &quot;265&quot;: case &quot;271&quot;: case &quot;274&quot;: case &quot;276&quot;: case &quot;277&quot;: case &quot;279&quot;: case &quot;280&quot;: case &quot;282&quot;: case &quot;283&quot;: case &quot;284&quot;: case &quot;289&quot;: case &quot;293&quot;: case &quot;294&quot;: case &quot;299&quot;: case &quot;300&quot;: case &quot;305&quot;: case &quot;306&quot;:
#                     return {&quot;color&quot;: &quot;#666666&quot;, &quot;fillColor&quot;: &quot;#666666&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#1b9e77&quot;, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_17aa4f2258207f88e2b8cc7f36eea7df_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75}

# %% [markdown]
# ## Budget cuts incoming!
#
# <div class="alert alert-warning">
#
# Using the methods we discussed above, can you create a new MCLP problem object to cover as many Bristol post codes as possible with six facilities and a 5000 meter service radius? What facilities are not covered?
#
# </div>

# %%
mclp1 = spopt.locate.MCLP.from_geodataframe(
    gdf_demand=bristol_postcodes,
    gdf_fac=bristol_postcodes,
    service_radius = 5000,
    p_facilities=6,
    weights_cols='demand',
    demand_col="geometry", 
    facility_col="geometry",
).solve(pulp.COIN_CMD(msg=False))

# %%
bristol_postcodes.assign(
    allocation = [str(assignment) for assignment in mclp1.cli2fac]
).explore('allocation',
         marker_kwds=dict(radius=10),
          cmap='Dark2'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f02307a56ee839c6d56a1b1e0e63cae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend allocation&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;allocation&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[0]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[21]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[27]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[28]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[30]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[40]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[]&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f02307a56ee839c6d56a1b1e0e63cae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f02307a56ee839c6d56a1b1e0e63cae = L.map(
#                 &quot;map_7f02307a56ee839c6d56a1b1e0e63cae&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7f02307a56ee839c6d56a1b1e0e63cae);
#
#
#
#
#
#             var tile_layer_30f928510be31a23bea3cb0c7bcfe1bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7f02307a56ee839c6d56a1b1e0e63cae);
#
#
#             map_7f02307a56ee839c6d56a1b1e0e63cae.fitBounds(
#                 [[51.223946999999995, -2.991015], [51.646466999999994, -2.194994]],
#                 {}
#             );
#
#
#         function geo_json_3545d3ef9e51ab6b707f59e6822fc909_styler(feature) {
#             switch(feature.id) {
#                 case &quot;264&quot;: case &quot;267&quot;: case &quot;268&quot;: case &quot;272&quot;: case &quot;275&quot;: case &quot;286&quot;: case &quot;295&quot;: case &quot;298&quot;: case &quot;301&quot;: case &quot;302&quot;: case &quot;303&quot;: case &quot;305&quot;: case &quot;306&quot;:
#                     return {&quot;color&quot;: &quot;#1b9e77&quot;, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.5, &

# %% [markdown]
# #

# %%
chosen = [len(clients) > 0 for clients in mclp1.fac2cli]
sum(chosen)
# Out:
# 6

# %% [markdown]
# ## Introduce capacity
#
# Let's assume that each facility can only serve 1000 inhabitants. Let's create a column for this in our dataframe:
#
# ```python
# bristol_postcodes['capacity'] = 1_000
# ```
#
# <div class="alert alert-warning">
#
# Using the methods we discussed above and the `facility_capacity_col`, can you create a new LSCP problem object that includes this capacity constraint on facilities? How does it differ from the initial LSCP solution?
#
# </div>

# %%
bristol_postcodes['capacity'] = 1_000

# %%
# this may bug out on old versions of spopt!

# %%
lscp2 = spopt.locate.LSCP.from_geodataframe(
    gdf_demand=bristol_postcodes,
    gdf_fac=bristol_postcodes,
    service_radius = 5000,
    facility_capacity_col='capacity',
    demand_quantity_col='demand',
    demand_col="geometry",
    facility_col="geometry",
).solve(pulp.COIN_CMD(msg=False))

# %%
bristol_postcodes.assign(
    allocation = [str(assignment) for assignment in lscp1.cli2fac]
).explore('allocation',
         marker_kwds=dict(radius=10),
          cmap='Dark2'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9f229ad430a7115c919c574d99e629b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend allocation&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;allocation&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[10]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[12]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[13]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[15]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[16]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[18]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[19]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[1]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[20]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[25]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[29]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[30]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[35]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[36]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[41, 42]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[41]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[42]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[7]&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9f229ad430a7115c919c574d99e629b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9f229ad430a7115c919c574d99e629b = L.map(
#                 &quot;map_a9f229ad430a7115c919c574d99e629b&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a9f229ad430a7115c919c574d99e629b);
#
#
#
#
#
#             var tile_layer_be14f748664010996047acd695d27a42 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blan

# %%
bristol_postcodes.assign(
    allocation = [str(assignment) for assignment in lscp2.cli2fac]
).explore('allocation',
         marker_kwds=dict(radius=10),
          cmap='Dark2'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e32542be7dc893cf39179aa7804ab73c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend allocation&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;allocation&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[10]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[12]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[13]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[14, 17, 21]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[14]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[15]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[17]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[1]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[20]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[21]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[27]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[29]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[32]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[34, 42]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[34]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[35]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[42]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[5, 34]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[5]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[7, 34]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[7]&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e32542be7dc893cf39179aa7804ab73c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e32542be7dc893cf39179aa7804ab73c = L.map(
#                 &quot;map_e32542be7dc893cf39179aa7804ab73c&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e32542be7dc893cf39179aa7804ab73c);
#
#
#
#
#
#             var tile_layer_2d55b21fcd16d12c60

# %% [markdown]
# The assignments definitely change, primarily in the center city where the demand is highest.

# %% [markdown]
# ## MCLP is not PMedian
#
# <div class="alert alert-warning">
#
# Solve a P-Median problem for the same number of facilities (six) as our previous MCLP example. How do the MCLP/P-Median model solutions differ?
#
# </div>

# %%
pmedian = spopt.locate.PMedian.from_geodataframe(
    gdf_demand=bristol_postcodes,
    gdf_fac=bristol_postcodes,
    p_facilities=6,
    weights_cols='demand',
    demand_col="geometry", 
    facility_col="geometry",
).solve(pulp.COIN_CMD(msg=False))

# %% [markdown]
# ## Challenge: Bristol is far from an isometric plane!
#
# <div class="alert alert-warning">
#
# Using `spopt.locate.LSCP.from_cost_matrix()` function, can you create a new `LSCP` problem object to cover facilities using a 10 kilometer limit on the trip costs? How does this differ from your euclidean-based solution in the first question?
#
# </div>

# %%
cost_table = pandas.read_csv("../cost_table.csv")
cost_matrix = cost_table.pivot(index="destination_postcode", columns="origin_postcode", values="travel_cost")

# %%
cost_matrix
# Out:
# origin_postcode           BS1     BS10     BS11     BS12     BS13     BS14  \
# destination_postcode
# BS1                       0.0  16534.7   7448.0   4906.5   2110.4   8998.0
# BS10                  17665.2      0.0  15748.4   7790.1  17054.7  23942.4
# BS11                   7541.9  11710.0      0.0   7844.6  12443.6  17599.2
# BS12                   4840.7   7809.4   6901.1      0.0   7714.4  14602.1
# BS13                   2951.0  17236.3  12473.6   7996.3      0.0   7039.3
# BS14                   9458.3  23743.6  17950.6  14503.6   7474.9      0.0
# BS15                  17894.6  19516.5  30467.9  14480.6  17284.1  18352.1
# BS16                  12684.7  14306.7  25258.1   9270.7  12074.2  16756.4
# BS17                   5849.8  16009.0  11812.7   6762.4   5239.3  12126.9
# BS18                  14108.4  30698.1  22600.7  25662.1  12125.0   5919.5
# BS19                  39329.3  38691.2  49642.5  35930.3  38718.8  34154.7
# BS2                    2966.1  17251.4  11590.3   8011.4    973.4   7875.0
# BS20                  13112.1  17657.7   9277.5  17512.3  15535.0  19948.4
# BS21                  22799.6  27297.5  18917.3  27152.1  21078.2  25588.0
# BS22                  28917.2  42129.2  33749.0  41983.9  28934.1  29144.6
# BS23                  39629.4  44127.3  35747.1  43981.9  42052.3  46465.8
# BS35                  17336.4  25026.6  21202.4
# BS36                   8601.9  15030.5  14262.4
# BS37                   3936.3  21315.0  20400.0
# BS39                  24727.7  15628.8  17076.9
# BS4                   23617.1   7705.1   9301.7
# BS40                  41477.0  17985.9  21926.5
# BS41                  27998.5   5052.6   8993.2
# BS43                  23487.3   6106.1  10046.8
# BS48                  34259.0  11313.1  15253.8
# BS49                  57147.9  20037.9  28843.3
# BS5                   20371.9   6099.3   7766.0
# BS6                   19708.0   6681.9   7102.1
# BS7                   16898.7   8427.5   9817.1
# BS73                      0.0  30622.5  22839.9
# BS8                   23506.4      0.0   4249.1
# BS9                   22599.2   4721.2      0.0
#
# [43 rows x 43 columns]

# %% [markdown]
# Let's make sure that the two are aligned before we use them:

# %%
assert (bristol_postcodes.outward == cost_matrix.index).all()
assert (bristol_postcodes.outward == cost_matrix.columns).all()

# %% [markdown]
# Since they are, we can proceed. If they weren't, we could ensure they are aligned using the following:
#
# ```python
# cost_matrix.loc[bristol_postcodes.outward.values, bristol_postcodes.outward.values]
# ```
# as long as the indices are aligned together. Then, we can estimate the LSCP using the `from_cost_matrix` method:

# %%
lscp_route = spopt.locate.LSCP.from_cost_matrix(
    cost_matrix.values, 
    service_radius = 10_000, 
).solve(pulp.COIN_CMD(msg=False))

# %% [markdown]
# Now, we can make a map of the route-based allocation, and you can read the euclidean-based allocation by hovering over each dot:

# %%
bristol_postcodes.assign(
    route_allocation = [str(assignment) for assignment in lscp_route.cli2fac],
    euclidean_allocation = [str(assignment) for assignment in lscp1.cli2fac]
).explore('route_allocation',
         marker_kwds=dict(radius=10),
          cmap='Dark2'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8432ee7f4da8bdd6b28957c04b966d91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend route_allocation&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;route_allocation&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[10]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1b9e77&#x27;&gt;&lt;/span&gt;[13]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#d95f02&#x27;&gt;&lt;/span&gt;[15]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[17]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7570b3&#x27;&gt;&lt;/span&gt;[20]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e7298a&#x27;&gt;&lt;/span&gt;[23]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[27]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#66a61e&#x27;&gt;&lt;/span&gt;[3, 23, 31]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e6ab02&#x27;&gt;&lt;/span&gt;[3, 23]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[3, 31]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#a6761d&#x27;&gt;&lt;/span&gt;[31]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[32]&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#666666&#x27;&gt;&lt;/span&gt;[3]&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8432ee7f4da8bdd6b28957c04b966d91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8432ee7f4da8bdd6b28957c04b966d91 = L.map(
#                 &quot;map_8432ee7f4da8bdd6b28957c04b966d91&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8432ee7f4da8bdd6b28957c04b966d91);
#
#
#
#
#
#             var tile_layer_674262ff9be86a72a13e0113dadfc858 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8432ee7f4da8bdd6b28957c04b966d91);
#
#
#             map_8432ee7f4da8bdd6b28957c04b966d91.fitBounds(
#                 [[51.223946999999995,

# %% [markdown]
# The full table of assignment can be constructed directly:

# %%
pandas.concat(
    (
        pandas.Series(lscp_route.cli2fac, name='route-based', index=bristol_postcodes.outward), 
        pandas.Series(lscp1.cli2fac, name='straight line', index=bristol_postcodes.outward)
    ),
    axis=1
)
# Out:
#          route-based straight line
# outward
# BS1          [3, 31]      [41, 42]
# BS10             [3]           [1]
# BS11             [3]          [42]
# BS12             [3]          [42]
# BS13         [3, 31]      [41, 42]
# BS14            [31]          [30]
# BS15            [23]           [7]
# BS16         [3, 23]           [7]
# BS17     [3, 23, 31]           [7]
# BS18            [31]          [30]
# BS19            [10]          [10]
# BS2          [3, 31]      [41, 42]
# BS20            [13]          [12]
# BS21            [13]          [13]
# BS22            [17]          [36]
# BS23            [15]          [15]
# BS24            [15]          [16]
# BS25            [17]          [18]
# BS26            [17]          [18]
# BS27            [32]          [19]
# BS28            [20]          [20]
# BS29            [17]          [16]
# BS3             [31]          [41]
# BS30            [23]           [7]
# BS31            [31]          [30]
# BS32            [27]          [25]
# BS34            [27]           [1]
# BS35            [27]          [25]
# BS36         [3, 23]           [7]
# BS37            [23]          [29]
# BS39            [31]          [30]
# BS4             [31]          [41]
# BS40            [32]          [19]
# BS41            [31]          [41]
# BS43         [3, 31]          [41]
# BS48            [13]          [35]
# BS49            [13]          [36]
# BS5          [3, 31]          [41]
# BS6          [3, 31]           [7]
# BS7          [3, 31]           [7]
# BS73            [23]          [29]
# BS8          [3, 31]      [41, 42]
# BS9          [3, 31]      [41, 42]

# %% [markdown]
# You could also create a map showing the places where the assignment is the same (or similar)

# %%
n_cover_in_common = [
    len(set(a1).intersection(set(a2)))
    for a1, a2 in zip(lscp_route.cli2fac, lscp1.cli2fac)
]

# %%
bristol_postcodes.assign(
    n_cover_in_common = n_cover_in_common
).explore('n_cover_in_common',
         marker_kwds=dict(radius=10),
          cmap='Dark2_r'
         )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9960d1447b4fe73b15e335583f539c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9960d1447b4fe73b15e335583f539c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9960d1447b4fe73b15e335583f539c1 = L.map(
#                 &quot;map_c9960d1447b4fe73b15e335583f539c1&quot;,
#                 {
#                     center: [51.43520699999999, -2.5930045],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c9960d1447b4fe73b15e335583f539c1);
#
#
#
#
#
#             var tile_layer_120f4d0d70309c54139eda55ebffce92 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c9960d1447b4fe73b15e335583f539c1);
#
#
#             map_c9960d1447b4fe73b15e335583f539c1.fitBounds(
#                 [[51.223946999999995, -2.991015], [51.646466999999994, -2.194994]],
#                 {}
#             );
#
#
#         function geo_json_208d2aae94d70e40151b08e4439f64a0_styler(feature) {
#             switch(feature.id) {
#                 case &quot;274&quot;: case &quot;277&quot;: case &quot;279&quot;: case &quot;284&quot;:
#                     return {&quot;color&quot;: &quot;#1b9e77&quot;, &quot;fillColor&quot;: &quot;#1b9e77&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#666666&quot;, &quot;fillColor&quot;: &quot;#666666&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_208d2aae94d70e40151b08e4439f64a0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_208d2aae94d70e40151b08e4439f64a0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_208d2aae94d70e40151b08e4439f64a0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_208d2aae94d70e40151b08e4439f64a0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_208d2aae94d70e40151b08e4439f64a0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_208d2aae94d70e40151b08e4439f64a0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_208d2aae94d70e40151b08e4439f64a0 = L.geoJson(null, {
#                 onEachFeature: geo_json_208d2aae94d70e40151b08e4439f64a0_onEachFeature,
#
#                 style: geo_json_208d2aae94d70e40151b08e4439f64a0_styler,
#                 pointToLayer: geo_json_208d2aae94d70e40151b08e4439f64a0_pointToLayer
#         });
#
#         function geo_json_208d2aae94d70e40151b08e4439f64a0_add (data) {
#             geo_json_208d2aae94d70e40151b08e4439f64a0
#                 .addData(data)
#                 .addTo(map_c9960d1447b4fe73b15e335583f539c1);
#         }
#             geo_json_208d2aae94d70e40151b08e4439f64a0_add({&quot;bbox&quot;: [-2.991015, 51.223946999999995, -2.194994, 51.646466999999994], &quot;features&quot;: [{&quot;bbox&quot;: [-2.5918789999999996, 51.46634699999998, -2.5918789999999996, 51.4663469999

# %% [markdown]
# Only the most remote of the locations have a similar coverage structure. Otherwise, the route-based solution is quite distinct from the euclidean one. This is why the `spopt` library can use arbitrary `cost_matrix` for solving location-allocation problems.
